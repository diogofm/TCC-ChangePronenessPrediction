# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import lightgbm as lgb
import xgboost as xgb

from imblearn.over_sampling import SMOTE, ADASYN, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler, TomekLinks, EditedNearestNeighbours
from imblearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier, RandomForestClassifier

from sklearn.neighbors import KNeighborsClassifier


from sklearn.decomposition import pca

from sklearn.metrics import f1_score, roc_auc_score, confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold

from sklearn.preprocessing import MinMaxScaler

import pickle
import warnings
warnings.filterwarnings('ignore') 

from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score, roc_auc_score
def get_scores(y_test, y_pred):
    scores = []
    
    scores.append(f1_score(y_test, y_pred, average='micro'))
    #print("F1-Score(micro): " + str(scores[-1]))
    
    scores.append(f1_score(y_test, y_pred, average='macro'))
    #print("F1-Score(macro): " + str(scores[-1]))
    
    scores.append(f1_score(y_test, y_pred, average=None))
    #print("F1-Score(None): " + str(scores[-1]))
    
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    
    #Sensitivity
    sensitivity = tp / (tp+fn)
    scores.append(tp / (tp+fn))
    #print("Sensitivity: " + str(scores[-1]))
    
    #Specificity
    specificity = tn / (tn+fp)
    scores.append (tn / (tn+fp))
    #print("Specificity: " + str(scores[-1]))
    
    #VPP
    scores.append(tp / (tp+fp))
    #print("VPP: " + str(scores[-1]))
    
    #VPN
    scores.append(tn / (tn+fn))
    #print("VPN: " + str(scores[-1]))
    
    #RVP
    scores.append(sensitivity / (1-specificity))
    #print("RVP: " + str(scores[-1]))
    
    #RVN
    scores.append((1 - sensitivity) / specificity)
    #print("RVN: " + str(scores[-1]))
    
    #ROC_AUC
    scores.append(roc_auc_score(y_test, y_pred))
    #print("ROC_AUC: " + str(scores[-1]))
        
    scores.append([tn, fp, fn, tp])
    
    return scores

# %% [markdown]
# ### Data Set load and Normalization

# %%
df = pd.read_excel('all_releases_only_smells.xlsx')

k_fold = StratifiedKFold(10, random_state=42, shuffle=True)

scaler = MinMaxScaler()

X = df.drop(columns=['Path', 'will_change'])
X = pd.DataFrame(scaler.fit_transform(X))
y = pd.DataFrame(df.loc[:,'will_change'])

X = X.rename(columns={0:'f0', 1:'f1', 2:'f2', 3:'f3', 4:'f4', 5:'f5', 6:'f6', 7:'f7', 8:'f8', 9:'f9', 10:'f10', 11:'f11',
                      12:'f12', 13:'f13', 14:'f14', 15:'f15', 16:'f16', 17:'f17', 18:'f18', 19:'f19', 20:'f20', 21:'f21',
                      22:'f22', 23:'f23', 24:'f24', 25:'f25', 26:'f26', 27:'f27', 28:'f28', 29:'f29', 30:'f30', 31:'f31'})

# %% [markdown]
# ### GridSearch Parameters

# %%
parameters_svc_linear = {
        'clf__kernel':['linear'],
        'clf__C': [0.002, 1, 512, 1024, 2048], 
        'clf__class_weight':[{1:1}, {1:10}, {1:15}, {1:20}],
        'clf__max_iter': [10000]
    }

parameters_svc_rbf = {
        'clf__kernel':['rbf'],
        'clf__C': [0.002, 1, 512, 1024, 2048], 
        'clf__class_weight':[{1:1}, {1:10}, {1:15}, {1:20}],
        'clf__max_iter': [10000]
    }

parameters_dtc_grid = {
    'clf__criterion':('gini', 'entropy'), 
    'clf__min_samples_split':[0.1, 0.2, 0.3], 
    'clf__max_depth': [1, 10, 30, None],
    'clf__class_weight':[{1:1}, {1:10}, {1:20}, 'balanced'],
    'clf__presort':[False, True],
}

parameters_rfc_grid = { 
    'clf__n_estimators': [10, 50, 90],
    'clf__max_features': ['sqrt', 'log2'],
    'clf__max_depth' : [1, 10, 30, None],
    'clf__min_samples_split': [2, 8, 16],
    'clf__criterion' :['gini', 'entropy'],
    'clf__class_weight':[ {1:1}, {1:10}, {1:15}, {1:20}]
}

parameters_ABC_grid = {
    'clf__base_estimator__criterion' : ["gini", "entropy"],
    'clf__base_estimator__splitter' :   ["best", "random"],
    'clf__base_estimator__max_depth' : [1, 10, 30, None], 
    'clf__base_estimator__class_weight': [{1:1}, {1:10}, {1:15}, {1:20}], 
    'clf__n_estimators':  [10, 50, 90],
}


parameters_knn_grid = {'clf__n_neighbors': list(range(1,30))}


parameters_lr_grid = [{ 
                        'clf__penalty':['l2', 'l1'],
                        'clf__C':[0.0001, 0.001, 0.1, 1, 100, 1000],
                        }]

parameters_GBC = {
    "clf__loss":["deviance"],
    "clf__learning_rate": [0.01, 0.025, 0.05],
    "clf__max_depth": [None, 2, 4, 6, 10],
    "clf__max_features":["log2","sqrt"],
    "clf__criterion": ["friedman_mse",  "mae"],
    'clf__n_estimators': [64, 128, 256, 512] #[1, 2, 4, 16, 32, 64, 128, 256, 512]
    }


param_xgb_grid = {
           'clf__clf__n_estimators':  [10, 50, 90],
           'clf__clf__max_depth' : [1, 10, 30, None],
           'clf__learning_rate': [0.0001],
           'clf__min_child_weight': [1], #tuning min_child_weight subsample colsample_bytree for fighting against overfit
           'clf__random_state': [42] #ensemble xgboost with multiple seeds may reduce variance
             }

param_lgm_grid = {
    'clf__learning_rate': [0.005],
    'clf__n_estimators': [40],
    'clf__num_leaves': [6,8,12,16],
    'clf__boosting_type' : ['gbdt'],
    'clf__objective' : ['binary'],
    'clf__random_state' : [501], # Updated from 'seed'
    'clf__colsample_bytree' : [0.65, 0.66],
    'clf__subsample' : [0.7,0.75],
    'clf__reg_alpha' : [1,1.2],
    'clf__reg_lambda' : [1,1.2,1.4],
}
params = {'boosting_type': 'gbdt',
          'max_depth' : -1,
          'objective': 'binary',
          'nthread': 3, # Updated from nthread
          'num_leaves': 64,
          'learning_rate': 0.05,
          'max_bin': 512,
          'subsample_for_bin': 200,
          'subsample': 1,
          'subsample_freq': 1,
          'colsample_bytree': 0.8,
          'reg_alpha': 5,
          'reg_lambda': 10,
          'min_split_gain': 0.5,
          'min_child_weight': 1,
          'min_child_samples': 5,
          'scale_pos_weight': 1,
          'num_class' : 1,
          'metric' : 'binary_error'}

parameters_bag_grid = {
    'clf__base_estimator__max_depth' : [1, 2, 3, 4, 5],
    'clf__max_samples' : [0.05, 0.1, 0.2, 0.5]
}

# %%
results_dict = dict()

# %% [markdown]
# ## Sampler

# %%
sampler = ADASYN(random_state=42)

# %% [markdown]
# # Classifiers

# %% [markdown]
# ### Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['Logistic Regression - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['Logistic Regression - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6975377107364686
# Estimator and parameters:
# {'clf__C': 0.1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.645075421472937, 0.75]
#
# Fold: 2
# ROC_AUC: 0.6032470053238685
# Estimator and parameters:
# {'clf__C': 0.1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6752440106477373, 0.53]
#
# Fold: 3
# ROC_AUC: 0.6582048580301686
# Estimator and parameters:
# {'clf__C': 0.1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6601597160603372, 0.66]
#
# Fold: 4
# ROC_AUC: 0.7245745717068699
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6749555950266429, 0.77]
#
# Fold: 5
# ROC_AUC: 0.719245974904028
# Estimator and parameters:
# {'clf__C': 0.1, 'clf__penalty': 'l1'}
# [Confusion Matrix]: [0.6642984014209592, 0.77]
#
# Fold: 6
# ROC_AUC: 0.6973442961095514
# Estimator and parameters:
# {'clf__C': 0.1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6527531083481349, 0.74]
#
# Fold: 7
# ROC_AUC: 0.7267948203747207
# Estimator and parameters:
# {'clf__C': 0.1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6793960923623446, 0.77]
#
# Fold: 8
# ROC_AUC: 0.7358190568956627
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6651865008880995, 0.81]
#
# Fold: 9
# ROC_AUC: 0.6721910273305449
# Estimator and parameters:
# {'clf__C': 0.1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6669626998223801, 0.68]
#
# Fold: 10
# ROC_AUC: 0.6372686644129949
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6616341030195382, 0.61]
#
# Mean: 0.6872227985824877
# Std deviation: 0.04143955420593103
# CPU times: user 17.1 s, sys: 314 ms, total: 17.4 s
# Wall time: 56.6 s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### LightGBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lgb.LGBMClassifier(boosting_type= 'gbdt',
          objective = 'binary',
          n_jobs = 3, # Updated from 'nthread'
          silent = True,
          max_depth = params['max_depth'],
          max_bin = params['max_bin'],
          subsample_for_bin = params['subsample_for_bin'],
          subsample = params['subsample'],
          subsample_freq = params['subsample_freq'],
          min_split_gain = params['min_split_gain'],
          min_child_weight = params['min_child_weight'],
          min_child_samples = params['min_child_samples'],
          scale_pos_weight = params['scale_pos_weight']))
        ])

clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['LightGBM - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['LightGBM - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.667036379769299
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 12, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1.4, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.834072759538598, 0.5]
#
# Fold: 2
# ROC_AUC: 0.6519520851818987
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 16, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1.2, 'clf__reg_lambda': 1.2, 'clf__subsample': 0.75}
# [Confusion Matrix]: [0.8039041703637977, 0.5]
#
# Fold: 3
# ROC_AUC: 0.6941409716060337
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 12, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1.2, 'clf__reg_lambda': 1, 'clf__subsample': 0.75}
# [Confusion Matrix]: [0.7320319432120674, 0.66]
#
# Fold: 4
# ROC_AUC: 0.6935197387268665
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.75}
# [Confusion Matrix]: [0.8063943161634103, 0.58]
#
# Fold: 5
# ROC_AUC: 0.6423251017017132
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 8, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.75}
# [Confusion Matrix]: [0.8330373001776199, 0.45]
#
# Fold: 6
# ROC_AUC: 0.643499684867931
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.7708703374777975, 0.52]
#
# Fold: 7
# ROC_AUC: 0.731249641895376
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 12, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1.2, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.7850799289520426, 0.68]
#
# Fold: 8
# ROC_AUC: 0.6907121984759067
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1.4, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.8330373001776199, 0.55]
#
# Fold: 9
# ROC_AUC: 0.6623073397123703
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 16, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1.2, 'clf__reg_lambda': 1.4, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.8730017761989343, 0.45]
#
# Fold: 10
# ROC_AUC: 0.6288603678450696
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 12, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.8383658969804618, 0.42]
#
# Mean: 0.6705603509782465
# Std deviation: 0.029778619534674408
# CPU times: user 31.5 s, sys: 857 ms, total: 32.4 s
# Wall time: 15min 36s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', SVC(random_state=42))])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['SVM Linear - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['SVM Linear - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.649040594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.56]
#
# Fold: 2
# ROC_AUC: 0.602165594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.47]
#
# Fold: 3
# ROC_AUC: 0.6677711845607809
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7417923691215617, 0.59]
#
# Fold: 4
# ROC_AUC: 0.6677648541797971
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7548845470692718, 0.58]
#
# Fold: 5
# ROC_AUC: 0.6692402452300463
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7255772646536413, 0.61]
#
# Fold: 6
# ROC_AUC: 0.6790093393685899
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7451154529307282, 0.61]
#
# Fold: 7
# ROC_AUC: 0.696914570560935
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7486678507992895, 0.65]
#
# Fold: 8
# ROC_AUC: 0.7238440382742222
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7380106571936057, 0.71]
#
# Fold: 9
# ROC_AUC: 0.6337305907293875
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7513321492007105, 0.52]
#
# Fold: 10
# ROC_AUC: 0.6113848622013408
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.738898756660746, 0.48]
#
# Mean: 0.6600865874102437
# Std deviation: 0.035390017899627944
# CPU times: user 1min 59s, sys: 1.09 s, total: 2min
# Wall time: 1h 20min 47s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', SVC(random_state=42))])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['SVM RBF - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['SVM RBF - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.649040594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.56]
#
# Fold: 2
# ROC_AUC: 0.602165594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.47]
#
# Fold: 3
# ROC_AUC: 0.6677711845607809
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7417923691215617, 0.59]
#
# Fold: 4
# ROC_AUC: 0.6677648541797971
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7548845470692718, 0.58]
#
# Fold: 5
# ROC_AUC: 0.6692402452300463
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7255772646536413, 0.61]
#
# Fold: 6
# ROC_AUC: 0.6790093393685899
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7451154529307282, 0.61]
#
# Fold: 7
# ROC_AUC: 0.696914570560935
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7486678507992895, 0.65]
#
# Fold: 8
# ROC_AUC: 0.7238440382742222
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7380106571936057, 0.71]
#
# Fold: 9
# ROC_AUC: 0.6337305907293875
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7513321492007105, 0.52]
#
# Fold: 10
# ROC_AUC: 0.6113848622013408
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.738898756660746, 0.48]
#
# Mean: 0.6600865874102437
# Std deviation: 0.035390017899627944
# CPU times: user 1min 59s, sys: 708 ms, total: 1min 59s
# Wall time: 1h 20min 37s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['Decision Tree - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['Decision Tree - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6505102040816326
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.5510204081632653, 0.75]
#
# Fold: 2
# ROC_AUC: 0.6424273513753327
# Estimator and parameters:
# {'clf__class_weight': 'balanced', 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.5661047027506655, 0.72]
#
# Fold: 3
# ROC_AUC: 0.6442990239574089
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.5385980479148181, 0.75]
#
# Fold: 4
# ROC_AUC: 0.7042915258121812
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.6021314387211367, 0.81]
#
# Fold: 5
# ROC_AUC: 0.6951240474417005
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.6483126110124334, 0.74]
#
# Fold: 6
# ROC_AUC: 0.5415974331060563
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.11545293072824156, 0.97]
#
# Fold: 7
# ROC_AUC: 0.6860998109207587
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.6625222024866785, 0.71]
#
# Fold: 8
# ROC_AUC: 0.6486707156362803
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.716696269982238, 0.58]
#
# Fold: 9
# ROC_AUC: 0.6085629977654271
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.6687388987566607, 0.55]
#
# Fold: 10
# ROC_AUC: 0.5958431215263852
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.7078152753108348, 0.48]
#
# Mean: 0.6417426231623163
# Std deviation: 0.04700860096641911
# CPU times: user 56.4 s, sys: 2.72 s, total: 59.1 s
# Wall time: 14min 34s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Random Forest

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['Random Forest - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['Random Forest - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 15}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.0, 1.0]
#
# Fold: 2
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 10}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.0, 1.0]
#
# Fold: 3
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.0, 1.0]
#
# Fold: 4
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.0, 1.0]
#
# Fold: 5
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.0, 1.0]
#
# Fold: 6
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.0, 1.0]
#
# Fold: 7
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.0, 1.0]
#
# Fold: 8
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'gini', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.0, 1.0]
#
# Fold: 9
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.0, 1.0]
#
# Fold: 10
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.0, 1.0]
#
# Mean: 0.5
# Std deviation: 0.0
# CPU times: user 2min 47s, sys: 7.25 s, total: 2min 54s
# Wall time: 1h 28min 22s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['KNN - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['KNN - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6060198535936114
# Estimator and parameters:
# {'clf__n_neighbors': 28}
# [Confusion Matrix]: [0.9307897071872228, 0.28]
#
# Fold: 2
# ROC_AUC: 0.6417064108251996
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [0.9396628216503993, 0.34]
#
# Fold: 3
# ROC_AUC: 0.727026952085182
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [0.9228039041703638, 0.53]
#
# Fold: 4
# ROC_AUC: 0.6253222941614621
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [0.9280639431616341, 0.32]
#
# Fold: 5
# ROC_AUC: 0.5643585629977654
# Estimator and parameters:
# {'clf__n_neighbors': 28}
# [Confusion Matrix]: [0.9351687388987566, 0.19]
#
# Fold: 6
# ROC_AUC: 0.6840657766573083
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [0.91651865008881, 0.45]
#
# Fold: 7
# ROC_AUC: 0.7265369850455509
# Estimator and parameters:
# {'clf__n_neighbors': 27}
# [Confusion Matrix]: [0.9369449378330373, 0.52]
#
# Fold: 8
# ROC_AUC: 0.6370108290838252
# Estimator and parameters:
# {'clf__n_neighbors': 27}
# [Confusion Matrix]: [0.9191829484902309, 0.35]
#
# Fold: 9
# ROC_AUC: 0.5643585629977654
# Estimator and parameters:
# {'clf__n_neighbors': 28}
# [Confusion Matrix]: [0.9351687388987566, 0.19]
#
# Fold: 10
# ROC_AUC: 0.6100813613705379
# Estimator and parameters:
# {'clf__n_neighbors': 28}
# [Confusion Matrix]: [0.9298401420959147, 0.29]
#
# Mean: 0.6386487588818208
# Std deviation: 0.055413162350606504
# CPU times: user 49.5 s, sys: 614 ms, total: 50.2 s
# Wall time: 36min 21s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### XGBoost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))])

clf = GridSearchCV(base_clf, param_xgb_grid,  scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['XGBoost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['XGBoost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6273014640638864
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.6921029281277729, 0.56]
#
# Fold: 2
# ROC_AUC: 0.5727318101153505
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.582963620230701, 0.56]
#
# Fold: 3
# ROC_AUC: 0.6545031055900621
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.5590062111801242, 0.75]
#
# Fold: 4
# ROC_AUC: 0.6665759468286254
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7202486678507993, 0.61]
#
# Fold: 5
# ROC_AUC: 0.6723485933650375
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7317939609236235, 0.61]
#
# Fold: 6
# ROC_AUC: 0.6112272961668481
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.6740674955595026, 0.55]
#
# Fold: 7
# ROC_AUC: 0.7041626081475963
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7309058614564832, 0.68]
#
# Fold: 8
# ROC_AUC: 0.650446914570561
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7202486678507993, 0.58]
#
# Fold: 9
# ROC_AUC: 0.6236606887068126
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.6989342806394316, 0.55]
#
# Fold: 10
# ROC_AUC: 0.5647739643614279
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7424511545293073, 0.39]
#
# Mean: 0.6347732391916208
# Std deviation: 0.041660413751830626
# CPU times: user 16.5 s, sys: 386 ms, total: 16.9 s
# Wall time: 4min 7s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
