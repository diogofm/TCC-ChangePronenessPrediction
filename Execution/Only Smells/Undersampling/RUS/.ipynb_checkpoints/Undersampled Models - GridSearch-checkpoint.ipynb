# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import lightgbm as lgb
import xgboost as xgb

from imblearn.over_sampling import SMOTE, ADASYN, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler, TomekLinks, EditedNearestNeighbours
from imblearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier, RandomForestClassifier

from sklearn.neighbors import KNeighborsClassifier


from sklearn.decomposition import pca

from sklearn.metrics import f1_score, roc_auc_score, confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold

from sklearn.preprocessing import MinMaxScaler

import pickle
import warnings
warnings.filterwarnings('ignore') 

from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score, roc_auc_score
def get_scores(y_test, y_pred):
    scores = []
    
    scores.append(f1_score(y_test, y_pred, average='micro'))
    #print("F1-Score(micro): " + str(scores[-1]))
    
    scores.append(f1_score(y_test, y_pred, average='macro'))
    #print("F1-Score(macro): " + str(scores[-1]))
    
    scores.append(f1_score(y_test, y_pred, average=None))
    #print("F1-Score(None): " + str(scores[-1]))
    
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    
    #Sensitivity
    sensitivity = tp / (tp+fn)
    scores.append(tp / (tp+fn))
    #print("Sensitivity: " + str(scores[-1]))
    
    #Specificity
    specificity = tn / (tn+fp)
    scores.append (tn / (tn+fp))
    #print("Specificity: " + str(scores[-1]))
    
    #VPP
    scores.append(tp / (tp+fp))
    #print("VPP: " + str(scores[-1]))
    
    #VPN
    scores.append(tn / (tn+fn))
    #print("VPN: " + str(scores[-1]))
    
    #RVP
    scores.append(sensitivity / (1-specificity))
    #print("RVP: " + str(scores[-1]))
    
    #RVN
    scores.append((1 - sensitivity) / specificity)
    #print("RVN: " + str(scores[-1]))
    
    #ROC_AUC
    scores.append(roc_auc_score(y_test, y_pred))
    #print("ROC_AUC: " + str(scores[-1]))
        
    scores.append([tn, fp, fn, tp])
    
    return scores

# %% [markdown]
# ### Data Set load and Normalization

# %%
df = pd.read_excel('all_releases_only_smells.xlsx')

k_fold = StratifiedKFold(10, random_state=42, shuffle=True)

scaler = MinMaxScaler()

X = df.drop(columns=['Path', 'will_change'])
X = pd.DataFrame(scaler.fit_transform(X))
y = pd.DataFrame(df.loc[:,'will_change'])

X = X.rename(columns={0:'f0', 1:'f1', 2:'f2', 3:'f3', 4:'f4', 5:'f5', 6:'f6', 7:'f7', 8:'f8', 9:'f9', 10:'f10', 11:'f11',
                      12:'f12', 13:'f13', 14:'f14', 15:'f15', 16:'f16', 17:'f17', 18:'f18', 19:'f19', 20:'f20', 21:'f21',
                      22:'f22', 23:'f23', 24:'f24', 25:'f25', 26:'f26', 27:'f27', 28:'f28', 29:'f29', 30:'f30', 31:'f31'})

# %% [markdown]
# ### GridSearch Parameters

# %%
parameters_svc_linear = {
        'clf__kernel':['linear'],
        'clf__C': [0.002, 1, 512, 1024, 2048], 
        'clf__class_weight':[{1:1}, {1:10}, {1:15}, {1:20}],
        'clf__max_iter': [10000]
    }

parameters_svc_rbf = {
        'clf__kernel':['rbf'],
        'clf__C': [0.002, 1, 512, 1024, 2048], 
        'clf__class_weight':[{1:1}, {1:10}, {1:15}, {1:20}],
        'clf__max_iter': [10000]
    }

parameters_dtc_grid = {
    'clf__criterion':('gini', 'entropy'), 
    'clf__min_samples_split':[0.1, 0.2, 0.3], 
    'clf__max_depth': [1, 10, 30, None],
    'clf__class_weight':[{1:1}, {1:10}, {1:20}, 'balanced'],
    'clf__presort':[False, True],
}

parameters_rfc_grid = { 
    'clf__n_estimators': [10, 50, 90],
    'clf__max_features': ['sqrt', 'log2'],
    'clf__max_depth' : [1, 10, 30, None],
    'clf__min_samples_split': [2, 8, 16],
    'clf__criterion' :['gini', 'entropy'],
    'clf__class_weight':[ {1:1}, {1:10}, {1:15}, {1:20}]
}

parameters_ABC_grid = {
    'clf__base_estimator__criterion' : ["gini", "entropy"],
    'clf__base_estimator__splitter' :   ["best", "random"],
    'clf__base_estimator__max_depth' : [1, 10, 30, None], 
    'clf__base_estimator__class_weight': [{1:1}, {1:10}, {1:15}, {1:20}], 
    'clf__n_estimators':  [10, 50, 90],
}


parameters_knn_grid = {'clf__n_neighbors': list(range(1,30))}


parameters_lr_grid = [{ 
                        'clf__penalty':['l2', 'l1'],
                        'clf__C':[0.0001, 0.001, 0.1, 1, 100, 1000],
                        }]

parameters_GBC = {
    "clf__loss":["deviance"],
    "clf__learning_rate": [0.01, 0.025, 0.05],
    "clf__max_depth": [None, 2, 4, 6, 10],
    "clf__max_features":["log2","sqrt"],
    "clf__criterion": ["friedman_mse",  "mae"],
    'clf__n_estimators': [64, 128, 256, 512] #[1, 2, 4, 16, 32, 64, 128, 256, 512]
    }


param_xgb_grid = {
           'clf__clf__n_estimators':  [10, 50, 90],
           'clf__clf__max_depth' : [1, 10, 30, None],
           'clf__learning_rate': [0.0001],
           'clf__min_child_weight': [1], #tuning min_child_weight subsample colsample_bytree for fighting against overfit
           'clf__random_state': [42] #ensemble xgboost with multiple seeds may reduce variance
             }

param_lgm_grid = {
    'clf__learning_rate': [0.005],
    'clf__n_estimators': [40],
    'clf__num_leaves': [6,8,12,16],
    'clf__boosting_type' : ['gbdt'],
    'clf__objective' : ['binary'],
    'clf__random_state' : [501], # Updated from 'seed'
    'clf__colsample_bytree' : [0.65, 0.66],
    'clf__subsample' : [0.7,0.75],
    'clf__reg_alpha' : [1,1.2],
    'clf__reg_lambda' : [1,1.2,1.4],
}
params = {'boosting_type': 'gbdt',
          'max_depth' : -1,
          'objective': 'binary',
          'nthread': 3, # Updated from nthread
          'num_leaves': 64,
          'learning_rate': 0.05,
          'max_bin': 512,
          'subsample_for_bin': 200,
          'subsample': 1,
          'subsample_freq': 1,
          'colsample_bytree': 0.8,
          'reg_alpha': 5,
          'reg_lambda': 10,
          'min_split_gain': 0.5,
          'min_child_weight': 1,
          'min_child_samples': 5,
          'scale_pos_weight': 1,
          'num_class' : 1,
          'metric' : 'binary_error'}

parameters_bag_grid = {
    'clf__base_estimator__max_depth' : [1, 2, 3, 4, 5],
    'clf__max_samples' : [0.05, 0.1, 0.2, 0.5]
}

# %%
results_dict = dict()

# %% [markdown]
# ## Sampler

# %%
sampler = RandomUnderSampler(random_state=42)

# %% [markdown]
# # Classifiers

# %% [markdown]
# ### Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['Logistic Regression - RandomUnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['Logistic Regression - RandomUnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.64913764418811
# Estimator and parameters:
# {'clf__C': 100, 'clf__penalty': 'l1'}
# [Confusion Matrix]: [0.7045252883762201, 0.59]
#
# Fold: 2
# ROC_AUC: 0.6246395297249334
# Estimator and parameters:
# {'clf__C': 100, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.686779059449867, 0.56]
#
# Fold: 3
# ROC_AUC: 0.6433701197870453
# Estimator and parameters:
# {'clf__C': 100, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6929902395740906, 0.59]
#
# Fold: 4
# ROC_AUC: 0.6958689050593022
# Estimator and parameters:
# {'clf__C': 100, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6820603907637656, 0.71]
#
# Fold: 5
# ROC_AUC: 0.6535552627055521
# Estimator and parameters:
# {'clf__C': 1000, 'clf__penalty': 'l1'}
# [Confusion Matrix]: [0.7264653641207816, 0.58]
#
# Fold: 6
# ROC_AUC: 0.6884633014381482
# Estimator and parameters:
# {'clf__C': 100, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6349911190053286, 0.74]
#
# Fold: 7
# ROC_AUC: 0.7497278404858765
# Estimator and parameters:
# {'clf__C': 100, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6607460035523979, 0.84]
#
# Fold: 8
# ROC_AUC: 0.7293158769266029
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.716696269982238, 0.74]
#
# Fold: 9
# ROC_AUC: 0.72132298172234
# Estimator and parameters:
# {'clf__C': 100, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.7007104795737122, 0.74]
#
# Fold: 10
# ROC_AUC: 0.634017074428465
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.6873889875666075, 0.58]
#
# Mean: 0.6789418536466376
# Std deviation: 0.041817027071149655
# CPU times: user 12.9 s, sys: 213 ms, total: 13.1 s
# Wall time: 5.4 s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### LightGBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lgb.LGBMClassifier(boosting_type= 'gbdt',
          objective = 'binary',
          n_jobs = 3, # Updated from 'nthread'
          silent = True,
          max_depth = params['max_depth'],
          max_bin = params['max_bin'],
          subsample_for_bin = params['subsample_for_bin'],
          subsample = params['subsample'],
          subsample_freq = params['subsample_freq'],
          min_split_gain = params['min_split_gain'],
          min_child_weight = params['min_child_weight'],
          min_child_samples = params['min_child_samples'],
          scale_pos_weight = params['scale_pos_weight']))
        ])

clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['LightGBM - RandomUnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['LightGBM - RandomUnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6706826752440107
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 12, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1.2, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.8101153504880213, 0.53]
#
# Fold: 2
# ROC_AUC: 0.5884122670807453
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 8, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.7080745341614907, 0.47]
#
# Fold: 3
# ROC_AUC: 0.6527839396628217
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1.2, 'clf__reg_lambda': 1, 'clf__subsample': 0.75}
# [Confusion Matrix]: [0.6805678793256433, 0.62]
#
# Fold: 4
# ROC_AUC: 0.6813871540709333
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 8, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1.2, 'clf__reg_lambda': 1.2, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.8143872113676732, 0.55]
#
# Fold: 5
# ROC_AUC: 0.6896665329742737
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 12, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1.2, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.7664298401420959, 0.61]
#
# Fold: 6
# ROC_AUC: 0.6983899616111844
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 8, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1.2, 'clf__reg_lambda': 1.4, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.7193605683836589, 0.68]
#
# Fold: 7
# ROC_AUC: 0.7441270841689107
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 12, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1.2, 'clf__reg_lambda': 1.2, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.8108348134991119, 0.68]
#
# Fold: 8
# ROC_AUC: 0.6942502721595141
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1.2, 'clf__reg_lambda': 1, 'clf__subsample': 0.75}
# [Confusion Matrix]: [0.7433392539964476, 0.65]
#
# Fold: 9
# ROC_AUC: 0.6423107775167592
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 12, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.7362344582593251, 0.55]
#
# Fold: 10
# ROC_AUC: 0.6150805019194407
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.7}
# [Confusion Matrix]: [0.7140319715808171, 0.52]
#
# Mean: 0.6677091166408594
# Std deviation: 0.04253129413968499
# CPU times: user 13.8 s, sys: 421 ms, total: 14.3 s
# Wall time: 2min 38s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', SVC(random_state=42))])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['SVM Linear - RandomUnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['SVM Linear - RandomUnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.649040594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.56]
#
# Fold: 2
# ROC_AUC: 0.6155723158828749
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7311446317657497, 0.5]
#
# Fold: 3
# ROC_AUC: 0.6677711845607809
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7417923691215617, 0.59]
#
# Fold: 4
# ROC_AUC: 0.6951383716266544
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7451154529307282, 0.65]
#
# Fold: 5
# ROC_AUC: 0.6634675986936343
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7140319715808171, 0.61]
#
# Fold: 6
# ROC_AUC: 0.6544290379877385
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.6314387211367674, 0.68]
#
# Fold: 7
# ROC_AUC: 0.708603105483298
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7397868561278863, 0.68]
#
# Fold: 8
# ROC_AUC: 0.7342004239958746
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7264653641207816, 0.74]
#
# Fold: 9
# ROC_AUC: 0.6332865409958174
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7504440497335702, 0.52]
#
# Fold: 10
# ROC_AUC: 0.6113848622013408
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.738898756660746, 0.48]
#
# Mean: 0.6632894035926682
# Std deviation: 0.037774181066478105
# CPU times: user 3.7 s, sys: 129 ms, total: 3.83 s
# Wall time: 33.5 s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', SVC(random_state=42))])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['SVM RBF - RandomUnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['SVM RBF - RandomUnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.649040594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.56]
#
# Fold: 2
# ROC_AUC: 0.6155723158828749
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7311446317657497, 0.5]
#
# Fold: 3
# ROC_AUC: 0.6677711845607809
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7417923691215617, 0.59]
#
# Fold: 4
# ROC_AUC: 0.6951383716266544
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7451154529307282, 0.65]
#
# Fold: 5
# ROC_AUC: 0.6634675986936343
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7140319715808171, 0.61]
#
# Fold: 6
# ROC_AUC: 0.6544290379877385
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.6314387211367674, 0.68]
#
# Fold: 7
# ROC_AUC: 0.708603105483298
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7397868561278863, 0.68]
#
# Fold: 8
# ROC_AUC: 0.7342004239958746
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7264653641207816, 0.74]
#
# Fold: 9
# ROC_AUC: 0.6332865409958174
# Estimator and parameters:
# {'clf__C': 1, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7504440497335702, 0.52]
#
# Fold: 10
# ROC_AUC: 0.6113848622013408
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 1}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.738898756660746, 0.48]
#
# Mean: 0.6632894035926682
# Std deviation: 0.037774181066478105
# CPU times: user 3.49 s, sys: 95.2 ms, total: 3.59 s
# Wall time: 33.6 s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['Decision Tree - RandomUnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['Decision Tree - RandomUnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6669254658385093
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.3, 'clf__presort': False}
# [Confusion Matrix]: [0.5838509316770186, 0.75]
#
# Fold: 2
# ROC_AUC: 0.5203111135758651
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.07187222715173026, 0.97]
#
# Fold: 3
# ROC_AUC: 0.6020685448092281
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.7666370896184561, 0.44]
#
# Fold: 4
# ROC_AUC: 0.716581676502607
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.6589698046181173, 0.77]
#
# Fold: 5
# ROC_AUC: 0.6823898470177046
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.5905861456483126, 0.77]
#
# Fold: 6
# ROC_AUC: 0.6783933994155733
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.5825932504440497, 0.77]
#
# Fold: 7
# ROC_AUC: 0.7270813040737982
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.6154529307282416, 0.84]
#
# Fold: 8
# ROC_AUC: 0.7045923336962127
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.6349911190053286, 0.77]
#
# Fold: 9
# ROC_AUC: 0.6392024293817682
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__min_samples_split': 0.3, 'clf__presort': False}
# [Confusion Matrix]: [0.7300177619893428, 0.55]
#
# Fold: 10
# ROC_AUC: 0.6178737179854465
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.5905861456483126, 0.65]
#
# Mean: 0.6555419832296713
# Std deviation: 0.059544025813559824
# CPU times: user 10.8 s, sys: 295 ms, total: 11.1 s
# Wall time: 37.1 s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Random Forest

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['Random Forest - RandomUnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['Random Forest - RandomUnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6840893966282166
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.805678793256433, 0.56]
#
# Fold: 2
# ROC_AUC: 0.6610192990239574
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 8, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.7595385980479148, 0.56]
#
# Fold: 3
# ROC_AUC: 0.70883706743567
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 1, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 10}
# [Confusion Matrix]: [0.8864241348713399, 0.53]
#
# Fold: 4
# ROC_AUC: 0.7164527588380221
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 2, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.7877442273534636, 0.65]
#
# Fold: 5
# ROC_AUC: 0.7019423594797456
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.7264653641207816, 0.68]
#
# Fold: 6
# ROC_AUC: 0.6828482209362288
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.6882770870337478, 0.68]
#
# Fold: 7
# ROC_AUC: 0.7626196069443649
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.783303730017762, 0.74]
#
# Fold: 8
# ROC_AUC: 0.6664327049790867
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.7522202486678508, 0.58]
#
# Fold: 9
# ROC_AUC: 0.6849252277545407
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.7246891651865008, 0.65]
#
# Fold: 10
# ROC_AUC: 0.5866756431559045
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 10}
# [Confusion Matrix]: [0.7539964476021315, 0.42]
#
# Mean: 0.6855842285175735
# Std deviation: 0.04296379647425997
# CPU times: user 50.6 s, sys: 1.35 s, total: 51.9 s
# Wall time: 10min 25s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['KNN - RandomUnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['KNN - RandomUnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6516609361135759
# Estimator and parameters:
# {'clf__n_neighbors': 13}
# [Confusion Matrix]: [0.8970718722271517, 0.41]
#
# Fold: 2
# ROC_AUC: 0.6101098047914818
# Estimator and parameters:
# {'clf__n_neighbors': 18}
# [Confusion Matrix]: [0.9077196095829636, 0.31]
#
# Fold: 3
# ROC_AUC: 0.6866542812777284
# Estimator and parameters:
# {'clf__n_neighbors': 17}
# [Confusion Matrix]: [0.842058562555457, 0.53]
#
# Fold: 4
# ROC_AUC: 0.6726637254340229
# Estimator and parameters:
# {'clf__n_neighbors': 17}
# [Confusion Matrix]: [0.8614564831261101, 0.48]
#
# Fold: 5
# ROC_AUC: 0.5649315303959205
# Estimator and parameters:
# {'clf__n_neighbors': 18}
# [Confusion Matrix]: [0.8072824156305506, 0.32]
#
# Fold: 6
# ROC_AUC: 0.6528390534578583
# Estimator and parameters:
# {'clf__n_neighbors': 16}
# [Confusion Matrix]: [0.8863232682060391, 0.42]
#
# Fold: 7
# ROC_AUC: 0.6873173666418381
# Estimator and parameters:
# {'clf__n_neighbors': 22}
# [Confusion Matrix]: [0.8907637655417406, 0.48]
#
# Fold: 8
# ROC_AUC: 0.7265226608605969
# Estimator and parameters:
# {'clf__n_neighbors': 16}
# [Confusion Matrix]: [0.8401420959147424, 0.61]
#
# Fold: 9
# ROC_AUC: 0.6574227926430987
# Estimator and parameters:
# {'clf__n_neighbors': 13}
# [Confusion Matrix]: [0.8632326820603907, 0.45]
#
# Fold: 10
# ROC_AUC: 0.5419841860998109
# Estimator and parameters:
# {'clf__n_neighbors': 22}
# [Confusion Matrix]: [0.7291296625222025, 0.35]
#
# Mean: 0.6452106337715933
# Std deviation: 0.05425616002548599
# CPU times: user 11.4 s, sys: 351 ms, total: 11.7 s
# Wall time: 1min 45s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### XGBoost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))])

clf = GridSearchCV(base_clf, param_xgb_grid,  scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['XGBoost - RandomUnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['XGBoost - RandomUnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6513559228039042
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7089618456078084, 0.59]
#
# Fold: 2
# ROC_AUC: 0.620355479148181
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.771960958296362, 0.47]
#
# Fold: 3
# ROC_AUC: 0.685517413487134
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7772848269742679, 0.59]
#
# Fold: 4
# ROC_AUC: 0.7115682117687503
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7779751332149201, 0.65]
#
# Fold: 5
# ROC_AUC: 0.7056236750128917
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.6047957371225577, 0.81]
#
# Fold: 6
# ROC_AUC: 0.6826906549017361
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.6234458259325044, 0.74]
#
# Fold: 7
# ROC_AUC: 0.7251761874749327
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7406749555950266, 0.71]
#
# Fold: 8
# ROC_AUC: 0.7134733283676159
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.6527531083481349, 0.77]
#
# Fold: 9
# ROC_AUC: 0.6319543917951067
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.7477797513321492, 0.52]
#
# Fold: 10
# ROC_AUC: 0.5887240016043087
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.5968028419182948, 0.58]
#
# Mean: 0.6716439266364562
# Std deviation: 0.04378533838399076
# CPU times: user 2.5 s, sys: 188 ms, total: 2.69 s
# Wall time: 15.9 s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
