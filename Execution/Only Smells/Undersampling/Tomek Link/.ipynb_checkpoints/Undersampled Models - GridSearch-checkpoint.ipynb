# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import lightgbm as lgb
import xgboost as xgb

from imblearn.over_sampling import SMOTE, ADASYN, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler, TomekLinks, EditedNearestNeighbours
from imblearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier, RandomForestClassifier

from sklearn.neighbors import KNeighborsClassifier


from sklearn.decomposition import pca

from sklearn.metrics import f1_score, roc_auc_score, confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold

from sklearn.preprocessing import MinMaxScaler

import pickle
import warnings
warnings.filterwarnings('ignore') 

from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score, roc_auc_score
def get_scores(y_test, y_pred):
    scores = []
    
    scores.append(f1_score(y_test, y_pred, average='micro'))
    #print("F1-Score(micro): " + str(scores[-1]))
    
    scores.append(f1_score(y_test, y_pred, average='macro'))
    #print("F1-Score(macro): " + str(scores[-1]))
    
    scores.append(f1_score(y_test, y_pred, average=None))
    #print("F1-Score(None): " + str(scores[-1]))
    
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    
    #Sensitivity
    sensitivity = tp / (tp+fn)
    scores.append(tp / (tp+fn))
    #print("Sensitivity: " + str(scores[-1]))
    
    #Specificity
    specificity = tn / (tn+fp)
    scores.append (tn / (tn+fp))
    #print("Specificity: " + str(scores[-1]))
    
    #VPP
    scores.append(tp / (tp+fp))
    #print("VPP: " + str(scores[-1]))
    
    #VPN
    scores.append(tn / (tn+fn))
    #print("VPN: " + str(scores[-1]))
    
    #RVP
    scores.append(sensitivity / (1-specificity))
    #print("RVP: " + str(scores[-1]))
    
    #RVN
    scores.append((1 - sensitivity) / specificity)
    #print("RVN: " + str(scores[-1]))
    
    #ROC_AUC
    scores.append(roc_auc_score(y_test, y_pred))
    #print("ROC_AUC: " + str(scores[-1]))
        
    scores.append([tn, fp, fn, tp])
    
    return scores

# %% [markdown]
# ### Data Set load and Normalization

# %%
df = pd.read_excel('all_releases_only_smells.xlsx')

k_fold = StratifiedKFold(10, random_state=42, shuffle=True)

scaler = MinMaxScaler()

X = df.drop(columns=['Path', 'will_change'])
X = pd.DataFrame(scaler.fit_transform(X))
y = pd.DataFrame(df.loc[:,'will_change'])

X = X.rename(columns={0:'f0', 1:'f1', 2:'f2', 3:'f3', 4:'f4', 5:'f5', 6:'f6', 7:'f7', 8:'f8', 9:'f9', 10:'f10', 11:'f11',
                      12:'f12', 13:'f13', 14:'f14', 15:'f15', 16:'f16', 17:'f17', 18:'f18', 19:'f19', 20:'f20', 21:'f21',
                      22:'f22', 23:'f23', 24:'f24', 25:'f25', 26:'f26', 27:'f27', 28:'f28', 29:'f29', 30:'f30', 31:'f31'})

# %% [markdown]
# ### GridSearch Parameters

# %%
parameters_svc_linear = {
        'clf__kernel':['linear'],
        'clf__C': [0.002, 1, 512, 1024, 2048], 
        'clf__class_weight':[{1:1}, {1:10}, {1:15}, {1:20}],
        'clf__max_iter': [10000]
    }

parameters_svc_rbf = {
        'clf__kernel':['rbf'],
        'clf__C': [0.002, 1, 512, 1024, 2048], 
        'clf__class_weight':[{1:1}, {1:10}, {1:15}, {1:20}],
        'clf__max_iter': [10000]
    }

parameters_dtc_grid = {
    'clf__criterion':('gini', 'entropy'), 
    'clf__min_samples_split':[0.1, 0.2, 0.3], 
    'clf__max_depth': [1, 10, 30, None],
    'clf__class_weight':[{1:1}, {1:10}, {1:20}, 'balanced'],
    'clf__presort':[False, True],
}

parameters_rfc_grid = { 
    'clf__n_estimators': [10, 50, 90],
    'clf__max_features': ['sqrt', 'log2'],
    'clf__max_depth' : [1, 10, 30, None],
    'clf__min_samples_split': [2, 8, 16],
    'clf__criterion' :['gini', 'entropy'],
    'clf__class_weight':[ {1:1}, {1:10}, {1:15}, {1:20}]
}

parameters_ABC_grid = {
    'clf__base_estimator__criterion' : ["gini", "entropy"],
    'clf__base_estimator__splitter' :   ["best", "random"],
    'clf__base_estimator__max_depth' : [1, 10, 30, None], 
    'clf__base_estimator__class_weight': [{1:1}, {1:10}, {1:15}, {1:20}], 
    'clf__n_estimators':  [10, 50, 90],
}


parameters_knn_grid = {'clf__n_neighbors': list(range(1,30))}


parameters_lr_grid = [{ 
                        'clf__penalty':['l2', 'l1'],
                        'clf__C':[0.0001, 0.001, 0.1, 1, 100, 1000],
                        }]

parameters_GBC = {
    "clf__loss":["deviance"],
    "clf__learning_rate": [0.01, 0.025, 0.05],
    "clf__max_depth": [None, 2, 4, 6, 10],
    "clf__max_features":["log2","sqrt"],
    "clf__criterion": ["friedman_mse",  "mae"],
    'clf__n_estimators': [64, 128, 256, 512] #[1, 2, 4, 16, 32, 64, 128, 256, 512]
    }


param_xgb_grid = {
           'clf__clf__n_estimators':  [10, 50, 90],
           'clf__clf__max_depth' : [1, 10, 30, None],
           'clf__learning_rate': [0.0001],
           'clf__min_child_weight': [1], #tuning min_child_weight subsample colsample_bytree for fighting against overfit
           'clf__random_state': [42] #ensemble xgboost with multiple seeds may reduce variance
             }

param_lgm_grid = {
    'clf__learning_rate': [0.005],
    'clf__n_estimators': [40],
    'clf__num_leaves': [6,8,12,16],
    'clf__boosting_type' : ['gbdt'],
    'clf__objective' : ['binary'],
    'clf__random_state' : [501], # Updated from 'seed'
    'clf__colsample_bytree' : [0.65, 0.66],
    'clf__subsample' : [0.7,0.75],
    'clf__reg_alpha' : [1,1.2],
    'clf__reg_lambda' : [1,1.2,1.4],
}
params = {'boosting_type': 'gbdt',
          'max_depth' : -1,
          'objective': 'binary',
          'nthread': 3, # Updated from nthread
          'num_leaves': 64,
          'learning_rate': 0.05,
          'max_bin': 512,
          'subsample_for_bin': 200,
          'subsample': 1,
          'subsample_freq': 1,
          'colsample_bytree': 0.8,
          'reg_alpha': 5,
          'reg_lambda': 10,
          'min_split_gain': 0.5,
          'min_child_weight': 1,
          'min_child_samples': 5,
          'scale_pos_weight': 1,
          'num_class' : 1,
          'metric' : 'binary_error'}

parameters_bag_grid = {
    'clf__base_estimator__max_depth' : [1, 2, 3, 4, 5],
    'clf__max_samples' : [0.05, 0.1, 0.2, 0.5]
}

# %%
results_dict = dict()

# %% [markdown]
# ## Sampler

# %%
sampler = TomekLinks(random_state=42)

# %% [markdown]
# # Classifiers

# %% [markdown]
# ### Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['Logistic Regression - TomekLinks'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['Logistic Regression - TomekLinks'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.515625
# Estimator and parameters:
# {'clf__C': 1000, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [1.0, 0.03]
#
# Fold: 2
# ROC_AUC: 0.515625
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [1.0, 0.03]
#
# Fold: 3
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 4
# ROC_AUC: 0.49955595026642985
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.9991119005328597, 0.0]
#
# Fold: 5
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l1'}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 6
# ROC_AUC: 0.5161290322580645
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [1.0, 0.03]
#
# Fold: 7
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 8
# ROC_AUC: 0.49822380106571934
# Estimator and parameters:
# {'clf__C': 100, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.9964476021314387, 0.0]
#
# Fold: 9
# ROC_AUC: 0.49866785079928955
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.9973357015985791, 0.0]
#
# Fold: 10
# ROC_AUC: 0.4991119005328597
# Estimator and parameters:
# {'clf__C': 1, 'clf__penalty': 'l2'}
# [Confusion Matrix]: [0.9982238010657194, 0.0]
#
# Mean: 0.5042938534922363
# Std deviation: 0.007549639451194335
# CPU times: user 36.2 s, sys: 406 ms, total: 36.6 s
# Wall time: 8min 41s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### LightGBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lgb.LGBMClassifier(boosting_type= 'gbdt',
          objective = 'binary',
          n_jobs = 3, # Updated from 'nthread'
          silent = True,
          max_depth = params['max_depth'],
          max_bin = params['max_bin'],
          subsample_for_bin = params['subsample_for_bin'],
          subsample = params['subsample'],
          subsample_freq = params['subsample_freq'],
          min_split_gain = params['min_split_gain'],
          min_child_weight = params['min_child_weight'],
          min_child_samples = params['min_child_samples'],
          scale_pos_weight = params['scale_pos_weight']))
        ])

clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['LightGBM - TomekLinks'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['LightGBM - TomekLinks'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 8, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1.2, 'clf__subsample': 0.7}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 2
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1.2, 'clf__subsample': 0.75}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 3
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.75}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 4
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 8, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.75}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 5
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 16, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.7}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 6
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1.4, 'clf__subsample': 0.75}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 7
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 6, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.7}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 8
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 8, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1.2, 'clf__reg_lambda': 1, 'clf__subsample': 0.75}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 9
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.66, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 8, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1, 'clf__subsample': 0.7}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 10
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__boosting_type': 'gbdt', 'clf__colsample_bytree': 0.65, 'clf__learning_rate': 0.005, 'clf__n_estimators': 40, 'clf__num_leaves': 16, 'clf__objective': 'binary', 'clf__random_state': 501, 'clf__reg_alpha': 1, 'clf__reg_lambda': 1.2, 'clf__subsample': 0.75}
# [Confusion Matrix]: [1.0, 0.0]
#
# Mean: 0.5
# Std deviation: 0.0
# CPU times: user 54.7 s, sys: 1.09 s, total: 55.7 s
# Wall time: 1h 11min 40s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', SVC(random_state=42))])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['SVM Linear - TomekLinks'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['SVM Linear - TomekLinks'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.649040594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.56]
#
# Fold: 2
# ROC_AUC: 0.602165594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.47]
#
# Fold: 3
# ROC_AUC: 0.6677711845607809
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7417923691215617, 0.59]
#
# Fold: 4
# ROC_AUC: 0.6677648541797971
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7548845470692718, 0.58]
#
# Fold: 5
# ROC_AUC: 0.6692402452300463
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7255772646536413, 0.61]
#
# Fold: 6
# ROC_AUC: 0.6790093393685899
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7451154529307282, 0.61]
#
# Fold: 7
# ROC_AUC: 0.696914570560935
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7486678507992895, 0.65]
#
# Fold: 8
# ROC_AUC: 0.7238440382742222
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7380106571936057, 0.71]
#
# Fold: 9
# ROC_AUC: 0.6337305907293875
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7513321492007105, 0.52]
#
# Fold: 10
# ROC_AUC: 0.6113848622013408
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.738898756660746, 0.48]
#
# Mean: 0.6600865874102437
# Std deviation: 0.035390017899627944
# CPU times: user 57.8 s, sys: 856 ms, total: 58.7 s
# Wall time: 23min 43s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', SVC(random_state=42))])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['SVM RBF - TomekLinks'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['SVM RBF - TomekLinks'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.649040594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.56]
#
# Fold: 2
# ROC_AUC: 0.602165594498669
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.735581188997338, 0.47]
#
# Fold: 3
# ROC_AUC: 0.6677711845607809
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7417923691215617, 0.59]
#
# Fold: 4
# ROC_AUC: 0.6677648541797971
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7548845470692718, 0.58]
#
# Fold: 5
# ROC_AUC: 0.6692402452300463
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7255772646536413, 0.61]
#
# Fold: 6
# ROC_AUC: 0.6790093393685899
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7451154529307282, 0.61]
#
# Fold: 7
# ROC_AUC: 0.696914570560935
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7486678507992895, 0.65]
#
# Fold: 8
# ROC_AUC: 0.7238440382742222
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7380106571936057, 0.71]
#
# Fold: 9
# ROC_AUC: 0.6337305907293875
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.7513321492007105, 0.52]
#
# Fold: 10
# ROC_AUC: 0.6113848622013408
# Estimator and parameters:
# {'clf__C': 0.002, 'clf__class_weight': {1: 20}, 'clf__kernel': 'linear', 'clf__max_iter': 10000}
# [Confusion Matrix]: [0.738898756660746, 0.48]
#
# Mean: 0.6600865874102437
# Std deviation: 0.035390017899627944
# CPU times: user 57.5 s, sys: 851 ms, total: 58.4 s
# Wall time: 23min 49s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['Decision Tree - TomekLinks'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['Decision Tree - TomekLinks'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 2
# ROC_AUC: 0.6136590505767524
# Estimator and parameters:
# {'clf__class_weight': {1: 10}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.3, 'clf__presort': False}
# [Confusion Matrix]: [0.9148181011535049, 0.31]
#
# Fold: 3
# ROC_AUC: 0.7172665261756876
# Estimator and parameters:
# {'clf__class_weight': {1: 10}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.9032830523513753, 0.53]
#
# Fold: 4
# ROC_AUC: 0.6661605454649631
# Estimator and parameters:
# {'clf__class_weight': {1: 10}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.9129662522202486, 0.42]
#
# Fold: 5
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 6
# ROC_AUC: 0.49955595026642985
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 30, 'clf__min_samples_split': 0.3, 'clf__presort': False}
# [Confusion Matrix]: [0.9991119005328597, 0.0]
#
# Fold: 7
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 8
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': None, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 9
# ROC_AUC: 0.6325703317481236
# Estimator and parameters:
# {'clf__class_weight': {1: 10}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.9103019538188277, 0.35]
#
# Fold: 10
# ROC_AUC: 0.6276857846788518
# Estimator and parameters:
# {'clf__class_weight': {1: 20}, 'clf__criterion': 'gini', 'clf__max_depth': 30, 'clf__min_samples_split': 0.2, 'clf__presort': False}
# [Confusion Matrix]: [0.9005328596802842, 0.35]
#
# Mean: 0.5756898188910808
# Std deviation: 0.08020081848401234
# CPU times: user 1min 15s, sys: 2.36 s, total: 1min 18s
# Wall time: 2h 14min 42s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Random Forest

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['Random Forest - TomekLinks'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['Random Forest - TomekLinks'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 2
# ROC_AUC: 0.5147376885536823
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.9982253771073647, 0.03]
#
# Fold: 3
# ROC_AUC: 0.5151813442768411
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.9991126885536823, 0.03]
#
# Fold: 4
# ROC_AUC: 0.49955595026642985
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.9991119005328597, 0.0]
#
# Fold: 5
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 50}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 6
# ROC_AUC: 0.49866785079928955
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 50}
# [Confusion Matrix]: [0.9973357015985791, 0.0]
#
# Fold: 7
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 8
# ROC_AUC: 0.49955595026642985
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.9991119005328597, 0.0]
#
# Fold: 9
# ROC_AUC: 0.49822380106571934
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'gini', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.9964476021314387, 0.0]
#
# Fold: 10
# ROC_AUC: 0.49822380106571934
# Estimator and parameters:
# {'clf__class_weight': {1: 1}, 'clf__criterion': 'entropy', 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_split': 16, 'clf__n_estimators': 90}
# [Confusion Matrix]: [0.9964476021314387, 0.0]
#
# Mean: 0.502414638629411
# Std deviation: 0.006307508446160584
# CPU times: user 3min 8s, sys: 8.27 s, total: 3min 17s
# Wall time: 7h 4min 25s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['KNN - TomekLinks'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['KNN - TomekLinks'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 2
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 3
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 4
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 5
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 6
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 7
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 27}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 8
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 9
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 27}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 10
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__n_neighbors': 29}
# [Confusion Matrix]: [1.0, 0.0]
#
# Mean: 0.5
# Std deviation: 0.0
# CPU times: user 1min 1s, sys: 686 ms, total: 1min 2s
# Wall time: 45min 36s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### XGBoost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))])

clf = GridSearchCV(base_clf, param_xgb_grid,  scoring='roc_auc', n_jobs=-1, cv=10)

scores_list = list()

results_dict['XGBoost - TomekLinks'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ')
    print(clf.best_params_)
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    print()
    
    results_dict['XGBoost - TomekLinks'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),str(clf.best_params_),'[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 2
# ROC_AUC: 0.49955634427684115
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.9991126885536823, 0.0]
#
# Fold: 3
# ROC_AUC: 0.515625
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [1.0, 0.03]
#
# Fold: 4
# ROC_AUC: 0.5318140147825589
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.9991119005328597, 0.06]
#
# Fold: 5
# ROC_AUC: 0.5161290322580645
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [1.0, 0.03]
#
# Fold: 6
# ROC_AUC: 0.4991119005328597
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.9982238010657194, 0.0]
#
# Fold: 7
# ROC_AUC: 0.5161290322580645
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [1.0, 0.03]
#
# Fold: 8
# ROC_AUC: 0.5
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [1.0, 0.0]
#
# Fold: 9
# ROC_AUC: 0.49866785079928955
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.9973357015985791, 0.0]
#
# Fold: 10
# ROC_AUC: 0.49866785079928955
# Estimator and parameters:
# {'clf__clf__max_depth': 1, 'clf__clf__n_estimators': 10, 'clf__learning_rate': 0.0001, 'clf__min_child_weight': 1, 'clf__random_state': 42}
# [Confusion Matrix]: [0.9973357015985791, 0.0]
#
# Mean: 0.5075701025706969
# Std deviation: 0.010991059045832105
# CPU times: user 33.6 s, sys: 385 ms, total: 34 s
# Wall time: 10min 28s

# %%
with open('partial_results_undersample.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
